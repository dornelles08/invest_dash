# %%
import pandas as pd

# %%
df = pd.read_csv("../data/transações.csv", sep=";")
df.head()
# Out:
#   Data de negociação   Ativo  Quantidade  Preço sem taxas
# 0         03/05/2023  BTLG11           2            94.66
# 1         03/05/2023  XPLG11           2            99.55
# 2         03/05/2023  KNCR11           2            95.17
# 3         03/05/2023  HSML11           2            84.98
# 4         03/05/2023  VGHF11          18             8.99

# %%
for index, row in df.iterrows():
    print({
        "ativo": row["Ativo"],
        "qtd": row["Quantidade"],
        "price": row["Preço sem taxas"],
        "date": row["Data de negociação"],
        "total": round(row["Quantidade"]*row["Preço sem taxas"], 2),
        "user_id": "668e76af007f1d8109df7b35"
    })
# Out:
# {'ativo': 'BTLG11', 'qtd': 2, 'price': 94.66, 'date': '03/05/2023', 'total': 189.32, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'XPLG11', 'qtd': 2, 'price': 99.55, 'date': '03/05/2023', 'total': 199.1, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'KNCR11', 'qtd': 2, 'price': 95.17, 'date': '03/05/2023', 'total': 190.34, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'HSML11', 'qtd': 2, 'price': 84.98, 'date': '03/05/2023', 'total': 169.96, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'VGHF11', 'qtd': 18, 'price': 8.99, 'date': '03/05/2023', 'total': 161.82, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'VISC11', 'qtd': 2, 'price': 107.06, 'date': '03/05/2023', 'total': 214.12, 'user_id': '668e76af007f1d8109df7b35'}
# {'ativo': 'KNSC11', 'qtd': 2, 'price': 85.08, 'date': '03/05/2023', 'total': 170.16, 'user_id': '668e76af007f1d8109df7b35'}
# ...
